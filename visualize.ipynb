# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import torch.nn as nn
import numpy as np
import argparse
import torch
from torch.nn.parameter import Parameter
import torch.nn.functional as F
from sklearn.cluster import KMeans
from torch.nn.modules.module import Module

from model import Model
from loss import loss


from Generator import HandWrtng
from Discriminators import Discr
from FTN import FTNet

from data import MNIST

from torchviz import make_dot,make_dot_from_trace

# %%
model = Model()
xs = torch.randn(5, 3, 32 ,32)
xsp = torch.randn(5,3,32,32)
xt = torch.randn(5,3,32,32)
r = model(xs, xsp, xt)
t = torch.from_numpy(np.array([0,1,2,3,4]))

l = loss(r[0], r[1], r[2], r[3], r[4], t, r[5], r[6], r[7], r[8], r[9])
# Out:
# torch.Size([5, 128, 4, 4])
# torch.Size([5, 128])
# torch.Size([5, 128, 4, 4])
# torch.Size([5, 128])
# torch.Size([5, 128, 4, 4])
# torch.Size([5, 128])
# torch.Size([5, 128]) torch.Size([5, 5])
# torch.Size([5, 128]) torch.Size([5, 5])
# torch.Size([5, 128]) torch.Size([5, 5])

# %%
make_dot(r, params=dict(list(model.named_parameters())))

# %%
r = model(xs, xsp, xt)
t = torch.from_numpy(np.array([0,1,2,3,4]))

l = loss(r[0], r[1], r[2], r[3], r[4], t, r[5], r[6], r[7], r[8], r[9])
make_dot(l[2], params=dict(list(model.named_parameters())))
# Out:
# torch.Size([5, 128, 4, 4])
# torch.Size([5, 128])
# torch.Size([5, 128, 4, 4])
# torch.Size([5, 128])
# torch.Size([5, 128, 4, 4])
# torch.Size([5, 128])
# torch.Size([5, 128]) torch.Size([5, 5])
# torch.Size([5, 128]) torch.Size([5, 5])
# torch.Size([5, 128]) torch.Size([5, 5])

# %%
for name, param in model.named_parameters():
    print(name, param.requires_grad)
# Out:
# gen.conv1_1.weight True
# gen.conv1_1.bias True
# gen.conv1_2.weight True
# gen.conv1_2.bias True
# gen.conv2_1.weight True
# gen.conv2_1.bias True
# gen.conv2_2.weight True
# gen.conv2_2.bias True
# gen.conv3_1.weight True
# gen.conv3_1.bias True
# gen.conv3_2.weight True
# gen.conv3_2.bias True
# gen.fc1.weight True
# gen.fc1.bias True
# gen.fc2.weight True
# gen.fc2.bias True
# D1.fc1.weight True
# D1.fc1.bias True
# D1.fc2.weight True
# D1.fc2.bias True
# D1.fc3.weight True
# D1.fc3.bias True
# D2.fc1.weight True
# D2.fc1.bias True
# D2.fc2.weight True
# D2.fc2.bias True
# D2.fc3.weight True
# D2.fc3.bias True
# FTN.fc1.weight True
# FTN.fc1.bias True
# FTN.fc2.weight True
# FTN.fc2.bias True
# FTN.fc3.weight True
# FTN.fc3.bias True
